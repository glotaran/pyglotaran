# %%
## Glotaran 2: a multi-way data analysis framework for global and target analysis in Python

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os
from glotaran.plotting.glotaran_color_codes import get_glotaran_default_colors_cycler
from cycler import cycler

from glotaran.dataio.wavelength_time_explicit_file import ExplicitFile
from glotaran.specification_parser import parse_yml

doGlobalAnalyis = True;

# %%
# THIS_DIR = os.path.realpath('.')
THIS_DIR = 'C:\\src\\glotaran\\tests\\notebooks'
root_data_path = os.path.join(THIS_DIR, '..', 'resources', 'data')
datapath_PAL_open = os.path.join(root_data_path, 'PAL_700_ma_tr2_gain50_10uW_590nmfilter_21C_400nm_AV_bc_sh_sel_620_830.ascii')
datapath_PAL_closed = os.path.join(root_data_path, 'PAL_DCMU_80uM_WL_SF_700_ma_tr2_gain50_100uW_590nmfilter_21C_400nm_AV_bc_sh_sel_620_830.ascii')
print(datapath_PAL_open)
print(datapath_PAL_closed)
prop_cycle=get_glotaran_default_colors_cycler()

# Read in data from resources/data sub-folder
# Dataset1
datafile_PAL_open = ExplicitFile(datapath_PAL_open)
dataset_PAL_open = datafile_PAL_open.read("dataset_PAL_open")
# Dataset2
datafile_PAL_closed = ExplicitFile(datapath_PAL_closed)
dataset_PAL_closed = datafile_PAL_closed.read("dataset_PAL_closed")

times1 = dataset_PAL_open.get_axis("time")
times2 = dataset_PAL_closed.get_axis("time")
wavelengths1 = dataset_PAL_open.get_axis("spectral")
wavelengths2 = dataset_PAL_closed.get_axis("spectral")
# Out:
# C:\src\glotaran\tests\notebooks\..\resources\data\PAL_700_ma_tr2_gain50_10uW_590nmfilter_21C_400nm_AV_bc_sh_sel_620_830.ascii
# C:\src\glotaran\tests\notebooks\..\resources\data\PAL_DCMU_80uM_WL_SF_700_ma_tr2_gain50_100uW_590nmfilter_21C_400nm_AV_bc_sh_sel_620_830.ascii

# %%
plt.figure()
plt.title('PAL_open')
plt.pcolormesh(times1, wavelengths1, dataset_PAL_open.data)

# %%
plt.figure(figsize=(12, 8))
plt.subplot(4, 4, 1)
plt.title('PAL_open')
plt.pcolormesh(times1, wavelengths1, dataset_PAL_open.data)
plt.subplot(4, 4, 5)
plt.title('PAL_closed')
plt.pcolormesh(times2, wavelengths2, dataset_PAL_closed.data)

rsvd1, svals1, lsvd1 = np.linalg.svd(dataset_PAL_open.data)
rsvd2, svals2, lsvd2 = np.linalg.svd(dataset_PAL_closed.data)
plt.subplot(4, 4, 2)
plt.title('LSV PAL open')
plt.rc('axes', prop_cycle=get_glotaran_default_colors_cycler())  # unsure why this is not working
for i in range(4):
    plt.plot(times1, lsvd1[i, :])
plt.subplot(4, 4, 6)
plt.title('LSV PAL closed')
plt.rc('axes', prop_cycle=get_glotaran_default_colors_cycler())  # because here it works
for i in range(4):
    plt.plot(times2, lsvd2[i, :])
# Plot singular values (SV)
plt.subplot(4, 4, 3)
plt.title('SVals PAL open')
plt.plot(range(max(10, min(len(times1), len(wavelengths1)))), svals1, 'ro')
plt.yscale('log')
plt.subplot(4, 4, 7)
plt.title('SVals PAL closed')
plt.plot(range(max(10, min(len(times2), len(wavelengths2)))), svals2, 'ro')
plt.yscale('log')
# Plot right singular vectors (RSV, wavelengths, first 3)
plt.subplot(4, 4, 4)
plt.title('RSV PAL open')
plt.rc('axes', prop_cycle=get_glotaran_default_colors_cycler())
for i in range(4):
    plt.plot(wavelengths1, rsvd1[:, i])
plt.subplot(4, 4, 8)
plt.title('RSV PAL closed')
plt.rc('axes', prop_cycle=get_glotaran_default_colors_cycler())
for i in range(4):
    plt.plot(wavelengths2, rsvd2[:, i])

plt.tight_layout()
plt.show()

# %%
fitspec1 = '''
type: kinetic

parameters: 
 - [1, {{vary: false}}]
 - [0, {{vary: false}}]
 - [0, {{vary: false}}]
 - [0, {{vary: false}}]
 - 101
 - 4.5
 - 0.3
 - 0.04
 - 0.01
 - 0.002

irf:
  - label: irf
    type: gaussian
    center: 5
    width: 6

compartments: [s1, s2, s3, s4]

megacomplexes:
    - label: mc1
      k_matrices: [k1]

k_matrices:
  - label: "k1"
    matrix: {{
      '("s2","s1")': 7,
      '("s3","s2")': 8,
      '("s4","s3")': 9,
      '("s4","s4")': 10
    }}

initial_concentration: #equal to the total number of compartments
  - label: inputD1
    parameter: [1, 2, 3, 4] 

datasets:
  - label: {}
    type: spectral
    initial_concentration: inputD1
    megacomplexes: [mc1]
    path: ''
    irf: irf

'''

specfit_model1 = parse_yml(fitspec1.format('dataset1'))
specfit_model1.datasets['dataset1'].data = dataset_PAL_open

# %%
if doGlobalAnalyis:

    specfit_result1 = specfit_model1.fit()
    specfit_result1.best_fit_parameter.pretty_print()
    residual1 = specfit_result1.final_residual()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-20-646771670de1> in <module>()
#       1 if doGlobalAnalyis:
#       2
# ----> 3     specfit_result1 = specfit_model1.fit()
#       4     specfit_result1.best_fit_parameter.pretty_print()
#       5     residual1 = specfit_result1.final_residual()
#
# C:\src\glotaran\glotaran\model\model.py in fit(self, nnls, *args, **kwargs)
#      43         if any([dset.data is None for _, dset in self.datasets.items()]):
#      44             raise Exception("Model datasets not initialized")
# ---> 45         return self.fit_model().fit(nnls, *args, **kwargs)
#      46
#      47     def fit_model(self):
#
# C:\src\glotaran\glotaran\fitmodel\fitmodel.py in fit(self, nnls, *args, **kwargs)
#      22         result = self.result(nnls, *args, **kwargs)
#      23
# ---> 24         result.fit(*args, **kwargs)
#      25         return result
#      26
#
# C:\WinPython\python\lib\site-packages\lmfit_varpro-0.1.0-py3.6.egg\lmfit_varpro\result.py in fit(self, *args, **kwargs)
#      24                             ftol=kwargs.get('ftol', 1e-10),
#      25                             gtol=kwargs.get('gtol', 1e-10),
# ---> 26                             verbose=verbose)
#      27
#      28         self.best_fit_parameter = res.params
#
# C:\WinPython\python\lib\site-packages\lmfit\minimizer.py in minimize(self, method, params, **kws)
#    1240                     val.lower().startswith(user_method)):
#    1241                     kwargs['method'] = val
# -> 1242         return function(**kwargs)
#    1243
#    1244
#
# C:\WinPython\python\lib\site-packages\lmfit\minimizer.py in least_squares(self, params, **kws)
#     999                             bounds=(lower_bounds, upper_bounds),
#    1000                             kwargs=dict(apply_bounds_transformation=False),
# -> 1001                             **kws
#    1002                             )
#    1003
#
# C:\WinPython\python\lib\site-packages\scipy\optimize\_lsq\least_squares.py in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     797         x0 = make_strictly_feasible(x0, lb, ub)
#     798
# --> 799     f0 = fun_wrapped(x0)
#     800
#     801     if f0.ndim != 1:
#
# C:\WinPython\python\lib\site-packages\scipy\optimize\_lsq\least_squares.py in fun_wrapped(x)
#     792
#     793     def fun_wrapped(x):
# --> 794         return np.atleast_1d(fun(x, *args, **kwargs))
#     795
#     796     if method == 'trf':
#
# C:\WinPython\python\lib\site-packages\lmfit\minimizer.py in __residual(self, fvars, apply_bounds_transformation)
#     368         self.result.nfev += 1
#     369
# --> 370         out = self.userfcn(params, *self.userargs, **self.userkws)
#     371         out = _nan_policy(out, nan_policy=self.nan_policy)
#     372
#
# C:\WinPython\python\lib\site-packages\lmfit_varpro-0.1.0-py3.6.egg\lmfit_varpro\result.py in _residual(self, parameter, *args, **kwargs)
#      61             residuals = np.concatenate(list(self._all_residuals(parameter,
#      62                                                                 *args,
# ---> 63                                                                 **kwargs)))
#      64         return residuals
#      65
#
# C:\WinPython\python\lib\site-packages\lmfit_varpro-0.1.0-py3.6.egg\lmfit_varpro\result.py in _all_residuals(self, parameter, *args, **kwargs)
#      68         data_group = self.model.data(**kwargs)
#      69         c_matrix_group = self.model.c_matrix(parameter,
# ---> 70                                              *args, **kwargs)
#      71         for data, c_mat in iter(data_group, c_matrix_group):
#      72             res = self._calculate_residual_qr(data, c_mat)
#
# C:\src\glotaran\glotaran\fitmodel\fitmodel.py in c_matrix(self, parameter, *args, **kwargs)
#      62                                                      self._model.
#      63                                                      calculated_matrix())
# ---> 64         return gen.calculate(parameter)
#      65
#      66     def e_matrix(self, parameter, *args, **kwargs):
#
# C:\src\glotaran\glotaran\fitmodel\matrix_group_generator.py in calculate(self, parameter)
#      53
#      54     def calculate(self, parameter):
# ---> 55         return [group.calculate(parameter) for group in self.groups()]
#      56
#      57     def create_dataset_group(self):
#
# C:\src\glotaran\glotaran\fitmodel\matrix_group_generator.py in <listcomp>(.0)
#      53
#      54     def calculate(self, parameter):
# ---> 55         return [group.calculate(parameter) for group in self.groups()]
#      56
#      57     def create_dataset_group(self):
#
# C:\src\glotaran\glotaran\fitmodel\matrix_group.py in calculate(self, parameter)
#      21             n_t = t_idx + mat.shape()[0]
#      22             mat.calculate(matrix[t_idx:n_t, :], compartment_order,
# ---> 23                           parameter)
#      24             t_idx = n_t
#      25
#
# C:\src\glotaran\glotaran\models\spectral_temporal\kinetic_c_matrix.py in calculate(self, c_matrix, compartment_order, parameter)
#      86
#      87             self._calculate_for_k_matrix(c_matrix, compartment_order, k_matrix,
# ---> 88                                          parameter, scale)
#      89
#      90     def _k_matrices_and_scalings(self):
#
# C:\src\glotaran\glotaran\models\spectral_temporal\kinetic_c_matrix.py in _calculate_for_k_matrix(self, c_matrix, compartment_order, k_matrix, parameter, scale)
#     134                                           scale * irf_scale,
#     135                                           backsweep,
# --> 136                                           backsweep_period,
#     137                                           )
#     138         # Apply equal equal constraints
#
# C:\src\glotaran\glotaran\models\spectral_temporal\c_matrix_cython\c_matrix_cython.py in c_matrix_gaussian_irf(self, C, idxs, rates, times, centers, widths, scale, backsweep, backsweep_period)
#      10                               scale, backsweep, backsweep_period):
#      11         calculateCSingleGaussian(C, idxs, rates, times, centers, widths,
# ---> 12                                  scale, backsweep, backsweep_period)
#
# C:\src\glotaran\glotaran\models\spectral_temporal\c_matrix_cython\c_matrix_gaussian_irf.pyx in c_matrix_gaussian_irf.calculateCSingleGaussian (glotaran/models/spectral_temporal/c_matrix_cython\c_matrix_gaussian_irf.c:2488)()
#      38             x_n = x[n_x]
#      39             beta = (x_n - mu) / (delta * sqrt(2))
# ---> 40             thresh = beta - alpha
#      41             if thresh < -1 :
#      42                 C[n_x, n_c] += scale * .5 * erfce(-thresh) * exp(-beta * beta)
#
# ZeroDivisionError: float division

# %%
if doGlobalAnalyis:

    plt.subplot(4, 4, 9)
    levels = np.linspace(0, max(dataset_PAL_open.data.flatten()), 10)
    cnt = plt.contourf(times1, wavelengths1, residual1, levels=levels, cmap="Greys")
    # This is the fix for the white lines between contour levels
    for c in cnt.collections:
        c.set_edgecolor("face")
    plt.title('Residuals')

    concentrations = specfit_result1.c_matrix('dataset1')
    plt.subplot(4, 4, 10)
    plt.title('Concentrations Open')
    plt.rc('axes', prop_cycle=get_glotaran_default_colors_cycler())
    plt.plot(times1, concentrations[0])

    spectra = specfit_result1.e_matrix('dataset1')
    plt.subplot(4, 4, 11)
    plt.title('EAS Open')
    plt.axhline(0, color='gray', linewidth=0.2)
    # plt.axvline(0, color='gray')
    plt.rc('axes', prop_cycle=get_glotaran_default_colors_cycler())
    for i in range(spectra.shape[1]):
        plt.plot(wavelengths1, spectra[:, i])
    plt.subplot(4, 4, 12)
    plt.title('norm EAS Open')
    plt.axhline(0, color='gray', linewidth=0.2)
    plt.rc('axes', prop_cycle=get_glotaran_default_colors_cycler())
    for i in range(spectra.shape[1]):
        scale = max(max(spectra[:, i]), abs(min(spectra[:, i])))
        plt.plot(wavelengths1, spectra[:, i] / scale)

    plt.tight_layout()
    plt.show(block=False)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-19-f7d37f894656> in <module>()
#       1 if doGlobalAnalyis:
#       2
# ----> 3     specfit_result1 = specfit_model1.fit()
#       4     specfit_result1.best_fit_parameter.pretty_print()
#       5     residual1 = specfit_result1.final_residual()
#
# C:\src\glotaran\glotaran\model\model.py in fit(self, nnls, *args, **kwargs)
#      43         if any([dset.data is None for _, dset in self.datasets.items()]):
#      44             raise Exception("Model datasets not initialized")
# ---> 45         return self.fit_model().fit(nnls, *args, **kwargs)
#      46
#      47     def fit_model(self):
#
# C:\src\glotaran\glotaran\fitmodel\fitmodel.py in fit(self, nnls, *args, **kwargs)
#      22         result = self.result(nnls, *args, **kwargs)
#      23
# ---> 24         result.fit(*args, **kwargs)
#      25         return result
#      26
#
# C:\WinPython\python\lib\site-packages\lmfit_varpro-0.1.0-py3.6.egg\lmfit_varpro\result.py in fit(self, *args, **kwargs)
#      24                             ftol=kwargs.get('ftol', 1e-10),
#      25                             gtol=kwargs.get('gtol', 1e-10),
# ---> 26                             verbose=verbose)
#      27
#      28         self.best_fit_parameter = res.params
#
# C:\WinPython\python\lib\site-packages\lmfit\minimizer.py in minimize(self, method, params, **kws)
#    1240                     val.lower().startswith(user_method)):
#    1241                     kwargs['method'] = val
# -> 1242         return function(**kwargs)
#    1243
#    1244
#
# C:\WinPython\python\lib\site-packages\lmfit\minimizer.py in least_squares(self, params, **kws)
#     999                             bounds=(lower_bounds, upper_bounds),
#    1000                             kwargs=dict(apply_bounds_transformation=False),
# -> 1001                             **kws
#    1002                             )
#    1003
#
# C:\WinPython\python\lib\site-packages\scipy\optimize\_lsq\least_squares.py in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     797         x0 = make_strictly_feasible(x0, lb, ub)
#     798
# --> 799     f0 = fun_wrapped(x0)
#     800
#     801     if f0.ndim != 1:
#
# C:\WinPython\python\lib\site-packages\scipy\optimize\_lsq\least_squares.py in fun_wrapped(x)
#     792
#     793     def fun_wrapped(x):
# --> 794         return np.atleast_1d(fun(x, *args, **kwargs))
#     795
#     796     if method == 'trf':
#
# C:\WinPython\python\lib\site-packages\lmfit\minimizer.py in __residual(self, fvars, apply_bounds_transformation)
#     368         self.result.nfev += 1
#     369
# --> 370         out = self.userfcn(params, *self.userargs, **self.userkws)
#     371         out = _nan_policy(out, nan_policy=self.nan_policy)
#     372
#
# C:\WinPython\python\lib\site-packages\lmfit_varpro-0.1.0-py3.6.egg\lmfit_varpro\result.py in _residual(self, parameter, *args, **kwargs)
#      61             residuals = np.concatenate(list(self._all_residuals(parameter,
#      62                                                                 *args,
# ---> 63                                                                 **kwargs)))
#      64         return residuals
#      65
#
# C:\WinPython\python\lib\site-packages\lmfit_varpro-0.1.0-py3.6.egg\lmfit_varpro\result.py in _all_residuals(self, parameter, *args, **kwargs)
#      68         data_group = self.model.data(**kwargs)
#      69         c_matrix_group = self.model.c_matrix(parameter,
# ---> 70                                              *args, **kwargs)
#      71         for data, c_mat in iter(data_group, c_matrix_group):
#      72             res = self._calculate_residual_qr(data, c_mat)
#
# C:\src\glotaran\glotaran\fitmodel\fitmodel.py in c_matrix(self, parameter, *args, **kwargs)
#      62                                                      self._model.
#      63                                                      calculated_matrix())
# ---> 64         return gen.calculate(parameter)
#      65
#      66     def e_matrix(self, parameter, *args, **kwargs):
#
# C:\src\glotaran\glotaran\fitmodel\matrix_group_generator.py in calculate(self, parameter)
#      53
#      54     def calculate(self, parameter):
# ---> 55         return [group.calculate(parameter) for group in self.groups()]
#      56
#      57     def create_dataset_group(self):
#
# C:\src\glotaran\glotaran\fitmodel\matrix_group_generator.py in <listcomp>(.0)
#      53
#      54     def calculate(self, parameter):
# ---> 55         return [group.calculate(parameter) for group in self.groups()]
#      56
#      57     def create_dataset_group(self):
#
# C:\src\glotaran\glotaran\fitmodel\matrix_group.py in calculate(self, parameter)
#      21             n_t = t_idx + mat.shape()[0]
#      22             mat.calculate(matrix[t_idx:n_t, :], compartment_order,
# ---> 23                           parameter)
#      24             t_idx = n_t
#      25
#
# C:\src\glotaran\glotaran\models\spectral_temporal\kinetic_c_matrix.py in calculate(self, c_matrix, compartment_order, parameter)
#      86
#      87             self._calculate_for_k_matrix(c_matrix, compartment_order, k_matrix,
# ---> 88                                          parameter, scale)
#      89
#      90     def _k_matrices_and_scalings(self):
#
# C:\src\glotaran\glotaran\models\spectral_temporal\kinetic_c_matrix.py in _calculate_for_k_matrix(self, c_matrix, compartment_order, k_matrix, parameter, scale)
#     134                                           scale * irf_scale,
#     135                                           backsweep,
# --> 136                                           backsweep_period,
#     137                                           )
#     138         # Apply equal equal constraints
#
# C:\src\glotaran\glotaran\models\spectral_temporal\c_matrix_cython\c_matrix_cython.py in c_matrix_gaussian_irf(self, C, idxs, rates, times, centers, widths, scale, backsweep, backsweep_period)
#      10                               scale, backsweep, backsweep_period):
#      11         calculateCSingleGaussian(C, idxs, rates, times, centers, widths,
# ---> 12                                  scale, backsweep, backsweep_period)
#
# C:\src\glotaran\glotaran\models\spectral_temporal\c_matrix_cython\c_matrix_gaussian_irf.pyx in c_matrix_gaussian_irf.calculateCSingleGaussian (glotaran/models/spectral_temporal/c_matrix_cython\c_matrix_gaussian_irf.c:2488)()
#      38             x_n = x[n_x]
#      39             beta = (x_n - mu) / (delta * sqrt(2))
# ---> 40             thresh = beta - alpha
#      41             if thresh < -1 :
#      42                 C[n_x, n_c] += scale * .5 * erfce(-thresh) * exp(-beta * beta)
#
# ZeroDivisionError: float division
